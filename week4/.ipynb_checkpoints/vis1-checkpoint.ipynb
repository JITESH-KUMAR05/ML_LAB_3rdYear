# %% [markdown]
# ## parametric and non parametric

# %%
# !pip install statsmodels
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
x = np.linspace(0,10,100)
y = np.sin(x) + np.random.normal(scale=0.3,size=100)

# %%
lowers_res=sm.nonparametric.lowess(y,x,frac=0.2)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([ 0.18974508, -0.30932228,  0.09238163, -0.04148356,  0.30607446,
#         0.40760389,  0.53989959,  0.15415067,  0.39029517,  0.67211168,
#         0.50682494,  1.20349616,  0.54506865,  1.30046962,  0.79180795,
#         0.83316887,  0.93750906,  1.55610657,  1.24831038,  0.87737197,
#         1.17153184,  1.13559711,  1.04723234,  1.42301965,  0.84657537,
#         0.90555455, -0.11034482,  0.73854082,  0.59859998,  0.18079557,
#        -0.91748127, -0.1702857 , -0.31889936, -0.90882703, -0.01834417,
#         0.10666884, -0.20760163, -0.86551858, -0.62691471, -1.10316898,
#        -0.72040217, -0.48162799, -1.24253489, -1.12099433, -1.05385423,
#        -1.09636186, -1.00769637, -0.88447547, -0.89089219, -1.26128243,
#        -0.92337789, -0.67528495, -1.66723603, -1.09528018, -1.00131355,
#        -0.80233719, -0.86818787, -0.53882224, -0.10038297, -0.06725275,
#         0.07243474,  0.69213275, -0.21858089,  0.44229273,  0.15765443,
#         0.40954361,  0.61463772,  1.19074861,  0.4628037 ,  0.18025247,
#         0.84966055,  0.78813721,  1.00207794,  0.84252552,  1.03198796,
#         1.18505994,  1.13896338,  1.0603783 ,  1.19003319,  0.86915084,
#         0.97889693,  0.93640206,  0.55910642,  1.41041961,  1.08184476,
#         1.2774709 ,  0.65725493,  0.7372853 ,  0.5457196 ,  0.34177629,
#         0.45708947,  0.12062978, -0.44469373, -0.09948306,  0.35443606,
#        -0.34899061,  0.08771674, -0.3726701 , -0.218454  , -0.682796  ])

# %%
plt.scatter(x,y,label='Data',alpha=0.6)

# %%
plt.scatter(x,y,label='Data',alpha=0.6)
plt.plot(lowers_res[:,0],lowers_res[:,1],color='red',label='Lowess')
plt.title('locally weighted regression(Lowess)')
plt.legend()
plt.show()
